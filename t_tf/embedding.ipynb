# %% [markdown]
# [udacity](https://github.com/tensorflow/examples/blob/master/courses/udacity_deep_learning/5_word2vec.ipynb)
#
# [学习Tensorflow的Embeddings例子](https://liusida.github.io/2016/11/14/study-embeddings/)

# %%
from __future__ import print_function
# %matplotlib inline
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
#from sklearn.manifold import TSNE

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

words = read_data("/Users/qtt/workspace/github/word2vec/text8.gz")
print('Word Num %d' % len(words))
print(words[0])
# Out:
# Word Num 17005207
# anarchism

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
#del words  # Hint to reduce memory
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

# %%
print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
  data_index = 0
  batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
  print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
  print('    batch:', [reverse_dictionary[bi] for bi in batch])
  print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'anarchism', 'originated', 'term', 'term', 'originated', 'as', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# WARNING:tensorflow:From /Users/qtt/.pyenv/versions/3.6.5/lib/python3.6/site-packages/tensorflow_core/python/training/adagrad.py:76: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
# Out:
# Initialized
# Average loss at step 0: 8.139551
# Nearest to up: orientational, marilyn, overlap, oeuvres, resolving, bumpy, amounting, world,
# Nearest to zero: derek, prerecorded, dong, dow, integrable, telangana, connected, fend,
# Nearest to history: skin, progressivism, hurry, gda, bangladeshi, griffon, gilead, silmarillion,
# Nearest to the: adults, artefacts, libya, coastline, magnet, scarlet, powder, courtier,
# Nearest to years: hab, stg, quan, backlight, mercantilists, etruscans, rangers, assures,
# Nearest to s: dar, prediction, recognised, teimanim, amber, adjoining, arians, futurians,
# Nearest to its: conjunction, alves, josie, patron, attractiveness, cody, precision, arise,
# Nearest to is: patti, propriety, donuts, ohio, exile, legnica, lyrics, lockheed,
# Nearest to state: transitioning, personalities, dixieland, ton, hadrian, ellipsoid, steamships, suffolk,
# Nearest to one: tele, writs, proficiency, ara, optics, polysaccharides, torches, matre,
# Nearest to has: nubia, caricom, acm, consuming, synodic, charleroi, great, catabolism,
# Nearest to people: comparison, groton, submits, hathor, vertical, gnomes, croats, salford,
# Nearest to will: turn, transclusion, cortical, refinement, humble, flensburg, military, apis,
# Nearest to such: siding, few, madero, submission, tornadoes, fuji, poem, adjutant,
# Nearest to about: downward, squire, shifted, stairs, yoshi, boneyard, eckert, knapp,
# Nearest to as: cnidaria, booed, portraiture, hutcheson, irenaeus, polygamy, trucks, daigo,
# Average loss at step 2000: 4.372160
# Average loss at step 4000: 3.860907
# Average loss at step 6000: 3.785583
# Average loss at step 8000: 3.684929
# Average loss at step 10000: 3.613442
# Nearest to up: orientational, marilyn, oeuvres, worcestershire, bumpy, meditating, sopra, alberta,
# Nearest to zero: six, seven, five, three, four, nine, eight, two,
# Nearest to history: skin, triggering, liberty, bollywood, number, hurry, progressivism, producers,
# Nearest to the: a, its, his, this, their, an, wingspan, departments,
# Nearest to years: hab, backlight, mercantilists, assures, etruscans, granada, embryos, proctor,
# Nearest to s: his, mimic, marrow, hammered, sire, ethnocentrism, harwich, voice,
# Nearest to its: the, their, his, shelled, this, roca, intrinsically, departments,
# Nearest to is: was, are, has, were, wandering, kwanzaa, garlic, devote,
# Nearest to state: transitioning, celebration, exhorts, hadrian, vidal, zeeland, excavated, desires,
# Nearest to one: two, six, four, seven, three, eight, five, pitcairn,
# Nearest to has: was, had, is, have, consuming, smothers, by, vehicular,
# Nearest to people: groton, votes, submits, coastline, technicality, specialize, architects, wire,
# Nearest to will: could, may, humble, can, refinement, linebacker, regarded, relaunched,
# Nearest to such: submission, few, fuji, madero, markschies, bukhara, panspermia, known,
# Nearest to about: made, downward, boneyard, correcting, on, hsv, dunant, work,
# Nearest to as: abner, defences, redaction, remy, rulebook, speedily, oversight, by,
# Average loss at step 12000: 3.607503
# Average loss at step 14000: 3.572023
# Average loss at step 16000: 3.412718
# Average loss at step 18000: 3.454888
# Average loss at step 20000: 3.542668
# Nearest to up: worcestershire, him, down, out, precautionary, mackinac, back, sopra,
# Nearest to zero: five, six, seven, four, three, eight, nine, two,
# Nearest to history: skin, triggering, producers, liberty, islam, wider, hurry, end,
# Nearest to the: its, their, this, a, any, his, some, wingspan,
# Nearest to years: assures, hab, months, secretly, backlight, sincerity, time, mercantilists,
# Nearest to s: signalling, investor, molyneux, arians, holst, unoccupied, chicks, yacc,
# Nearest to its: their, his, the, shelled, this, missourians, some, gandy,
# Nearest to is: was, has, are, be, but, were, does, maori,
# Nearest to state: exhorts, transitioning, rehearsing, ribbons, hadrian, forelimbs, celebration, scoreless,
# Nearest to one: two, four, three, six, five, seven, eight, pitcairn,
# Nearest to has: had, have, is, was, consuming, legislative, lending, osborn,
# Nearest to people: votes, groton, permittivity, smalltalk, hoisted, architects, men, ige,
# Nearest to will: could, may, would, can, relaunched, linebacker, refinement, cloth,
# Nearest to such: known, submission, few, these, well, lifeless, many, businesses,
# Nearest to about: made, dunant, on, gadgets, kul, hsv, kojiki, aquarii,
# Nearest to as: defences, item, widely, user, obstruction, polygamy, retains, programs,
# Average loss at step 22000: 3.496127
# Average loss at step 24000: 3.488064
# Average loss at step 26000: 3.479988
# Average loss at step 28000: 3.481105
# Average loss at step 30000: 3.498709
# Nearest to up: him, out, down, them, worcestershire, back, alibi, mackinac,
# Nearest to zero: five, eight, four, seven, six, three, nine, two,
# Nearest to history: skin, wider, bollywood, republic, gda, bidirectional, liberty, struggled,
# Nearest to the: its, their, his, a, mainline, wingspan, this, bazaar,
# Nearest to years: months, assures, days, hab, time, sincerity, backlight, secretly,
# Nearest to s: his, individualistic, differed, arians, and, molyneux, lok, hammered,
# Nearest to its: their, his, the, shelled, our, subsection, purim, her,
# Nearest to is: was, has, are, does, had, became, be, were,
# Nearest to state: exhorts, transitioning, ribbons, city, rehearsing, states, journal, hadrian,
# Nearest to one: two, four, seven, three, six, eight, five, nine,
# Nearest to has: had, have, is, was, consuming, legislative, having, gandhara,
# Nearest to people: votes, smalltalk, those, men, groton, histogram, architects, technicality,
# Nearest to will: would, can, could, may, should, might, must, relaunched,
# Nearest to such: well, these, many, submission, known, lifeless, few, reemergence,
# Nearest to about: on, dunant, szlachta, gadgets, correcting, made, tonk, aquarii,
# Nearest to as: redaction, by, daigo, abner, retrieving, with, remy, noncommercial,
# Average loss at step 32000: 3.503215
# Average loss at step 34000: 3.494565
# Average loss at step 36000: 3.456816
# Average loss at step 38000: 3.303059
# Average loss at step 40000: 3.430238
# Nearest to up: out, down, them, him, back, worcestershire, alibi, compares,
# Nearest to zero: five, seven, eight, nine, six, four, three, two,
# Nearest to history: islam, wider, skin, gda, php, bidirectional, revenues, ingest,
# Nearest to the: its, this, their, his, each, a, another, every,
# Nearest to years: months, days, year, assures, time, decades, glory, times,
# Nearest to s: his, nymphs, arians, and, roses, microcode, mahayana, cede,
# Nearest to its: their, his, the, her, cleanup, purim, shelled, intrinsically,
# Nearest to is: was, are, be, has, girl, as, if, became,
# Nearest to state: city, journal, exhorts, rehearsing, hadrian, angeles, transitioning, states,
# Nearest to one: seven, eight, four, two, six, three, five, bangui,
# Nearest to has: had, have, was, is, having, consuming, maximally, rumelia,
# Nearest to people: votes, those, insights, women, arguably, turbofan, groton, professing,
# Nearest to will: can, could, would, may, must, should, might, relaunched,
# Nearest to such: well, these, submission, known, many, follows, reemergence, constructivist,
# Nearest to about: aquarii, soundtrack, szlachta, categorised, notable, gadgets, meyers, hsv,
# Nearest to as: is, burglary, obstruction, redaction, pathologic, ashur, noncommercial, mullis,
# Average loss at step 42000: 3.431566
# Average loss at step 44000: 3.451719
# Average loss at step 46000: 3.449975
# Average loss at step 48000: 3.356315
# Average loss at step 50000: 3.381261
# Nearest to up: out, down, them, back, him, off, alibi, worcestershire,
# Nearest to zero: five, eight, seven, six, four, nine, three, two,
# Nearest to history: php, atv, islam, gda, revenues, list, storybook, ozone,
# Nearest to the: its, this, their, a, his, kilgore, ergot, any,
# Nearest to years: months, days, year, assures, decades, times, glory, time,
# Nearest to s: individualistic, baptise, powerpuff, and, heracleidae, marquis, harwich, molyneux,
# Nearest to its: their, his, the, her, missourians, cleanup, purim, samyaksam,
# Nearest to is: was, has, are, be, does, while, dhul, devote,
# Nearest to state: hadrian, states, pereira, exhorts, rehearsing, transitioning, journal, farm,
# Nearest to one: six, two, four, seven, eight, five, three, nine,
# Nearest to has: had, have, is, was, having, since, satavahana, osborn,
# Nearest to people: men, votes, smalltalk, groton, biafra, scored, students, women,
# Nearest to will: would, could, can, may, should, must, might, cannot,
# Nearest to such: these, well, known, many, submission, certain, businesses, follows,
# Nearest to about: soundtrack, aquarii, szlachta, lucille, macmullen, mazar, categorised, concert,
# Nearest to as: mullis, defences, redaction, by, rulebook, remy, cantigas, noncommercial,
# Average loss at step 52000: 3.435075
# Average loss at step 54000: 3.427840
# Average loss at step 56000: 3.438927
# Average loss at step 58000: 3.394767
# Average loss at step 60000: 3.390956
# Nearest to up: out, them, down, him, back, off, alibi, tents,
# Nearest to zero: five, eight, six, four, seven, nine, three, million,
# Nearest to history: list, culture, religion, demographics, islam, repeater, php, ingest,
# Nearest to the: its, their, a, this, his, some, our, gurps,
# Nearest to years: months, days, decades, year, assures, glory, times, hours,
# Nearest to s: curtain, arians, mispronounced, powerpuff, baptise, molyneux, operand, ops,
# Nearest to its: their, his, the, her, cleanup, gent, missourians, devo,
# Nearest to is: was, are, has, be, mei, contains, although, seems,
# Nearest to state: states, rehearsing, city, pereira, government, exhorts, fundamental, hadrian,
# Nearest to one: two, four, seven, six, eight, three, five, nine,
# Nearest to has: had, have, is, was, having, consuming, legislative, gives,
# Nearest to people: men, women, those, votes, students, scientists, biafra, others,
# Nearest to will: would, could, can, may, should, must, might, did,
# Nearest to such: known, these, well, many, certain, submission, photorealistic, few,
# Nearest to about: aquarii, soundtrack, lucille, macmullen, categorised, dunant, on, over,
# Nearest to as: like, heckler, obstruction, remy, cantigas, rulebook, become, lba,
# Average loss at step 62000: 3.242305
# Average loss at step 64000: 3.258800
# Average loss at step 66000: 3.403270
# Average loss at step 68000: 3.393096
# Average loss at step 70000: 3.357025
# Nearest to up: out, them, down, off, back, him, worcestershire, me,
# Nearest to zero: five, six, eight, four, seven, nine, three, two,
# Nearest to history: list, culture, religion, consists, php, form, period, milford,
# Nearest to the: its, their, a, this, any, byproduct, his, each,
# Nearest to years: months, days, decades, year, assures, centuries, glory, hours,
# Nearest to s: whose, powerpuff, sacked, the, operand, molyneux, baptise, chicks,
# Nearest to its: their, his, the, her, cleanup, shelled, our, punching,
# Nearest to is: was, has, are, be, does, although, mei, refers,
# Nearest to state: states, government, city, rehearsing, institutions, pereira, exhorts, journal,
# Nearest to one: two, six, seven, eight, four, five, three, nine,
# Nearest to has: had, have, is, was, consuming, happened, contains, having,
# Nearest to people: women, men, students, those, biafra, churchill, tasso, smalltalk,
# Nearest to will: would, could, can, may, must, should, might, shall,
# Nearest to such: these, known, well, certain, submission, photorealistic, many, few,
# Nearest to about: over, crushing, aquarii, soundtrack, macmullen, regarding, categorised, alicia,
# Nearest to as: like, pathologic, cantigas, oaths, mullis, when, sarin, dakini,
# Average loss at step 72000: 3.375374
# Average loss at step 74000: 3.348977
# Average loss at step 76000: 3.317523
# Average loss at step 78000: 3.354141
# Average loss at step 80000: 3.377601
# Nearest to up: out, down, them, off, him, back, respect, tents,
# Nearest to zero: seven, five, eight, six, four, three, nine, u,
# Nearest to history: list, milford, atv, culture, storybook, elixir, vis, php,
# Nearest to the: their, its, his, palomar, this, ngc, infix, a,
# Nearest to years: months, days, decades, year, weeks, centuries, glory, times,
# Nearest to s: colossians, whose, gtpase, yacc, wisely, roses, powerpuff, differed,
# Nearest to its: their, his, her, the, our, shelled, cleanup, pedal,
# Nearest to is: was, has, are, be, does, refers, jurisdictional, became,
# Nearest to state: city, government, exhorts, states, hadrian, rehearsing, fundamental, bumblebee,
# Nearest to one: seven, six, two, four, three, eight, five, guido,
# Nearest to has: had, have, is, was, although, subsist, having, since,
# Nearest to people: men, women, students, those, biafra, children, votes, scientists,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Nearest to such: these, well, certain, known, photorealistic, follows, submission, infringed,
# Nearest to about: aquarii, soundtrack, over, mamluks, categorised, approximately, around, crushing,
# Nearest to as: mullis, nationalistic, mmx, ferrari, when, pathologic, after, like,
# Average loss at step 82000: 3.407419
# Average loss at step 84000: 3.408297
# Average loss at step 86000: 3.391184
# Average loss at step 88000: 3.353067
# Average loss at step 90000: 3.365349
# Nearest to up: out, down, off, them, back, him, together, worcestershire,
# Nearest to zero: five, seven, eight, four, nine, six, three, two,
# Nearest to history: list, culture, atv, storybook, consists, introduction, translations, porfirio,
# Nearest to the: its, this, his, their, any, bedrock, a, liturgies,
# Nearest to years: days, months, decades, year, centuries, weeks, glory, hours,
# Nearest to s: whose, powerpuff, expos, mispronounced, baptise, arians, his, azali,
# Nearest to its: their, his, her, the, pedal, cleanup, shelled, our,
# Nearest to is: was, are, has, be, if, does, became, although,
# Nearest to state: city, government, rehearsing, protocol, party, exhorts, hadrian, fundamental,
# Nearest to one: seven, six, eight, four, two, three, five, nine,
# Nearest to has: had, have, is, was, since, having, gandhara, continues,
# Nearest to people: women, men, students, children, those, jews, man, scientists,
# Nearest to will: would, could, can, should, may, must, might, cannot,
# Nearest to such: these, known, well, certain, many, photorealistic, infringed, follows,
# Nearest to about: soundtrack, aquarii, categorised, concerning, over, crushing, concert, mamluks,
# Nearest to as: mullis, pathologic, nationalistic, remy, moniker, delved, heckler, hires,
# Average loss at step 92000: 3.397617
# Average loss at step 94000: 3.251480
# Average loss at step 96000: 3.358774
# Average loss at step 98000: 3.240290
# Average loss at step 100000: 3.359261
# Nearest to up: out, off, down, back, them, him, together, worcestershire,
# Nearest to zero: five, four, seven, eight, six, nine, three, two,
# Nearest to history: list, culture, atv, introduction, milford, php, consists, watered,
# Nearest to the: their, its, his, whose, a, this, your, our,
# Nearest to years: days, months, decades, centuries, year, weeks, hours, times,
# Nearest to s: whose, his, operand, webb, arians, the, pyramidal, powerpuff,
# Nearest to its: their, his, her, the, cleanup, our, macedonia, npd,
# Nearest to is: was, has, seems, refers, became, does, contains, be,
# Nearest to state: city, protocol, government, party, rehearsing, exhorts, department, bumblebee,
# Nearest to one: two, seven, four, six, three, five, nine, aspirant,
# Nearest to has: had, have, is, was, since, having, subsist, gandhara,
# Nearest to people: women, men, children, students, person, players, citizens, someone,
# Nearest to will: would, could, can, should, must, may, might, cannot,
# Nearest to such: known, well, these, many, certain, follows, including, photorealistic,
# Nearest to about: aquarii, soundtrack, mamluks, approximately, concerning, categorised, concert, around,
# Nearest to as: mullis, reinvent, like, pathologic, when, incensed, horton, obstruction,
