# %%
import operator
import random
import time
import math
import numpy
import pandas
from concurrent.futures import ProcessPoolExecutor
import slim

# %%
class Data:
    def __init__(self, dataset='ml-100k'):
        """
        无上下文信息的隐性反馈数据集。
        :param dataset: 使用的数据集名字，当前有'ml-100k','ml-1m'
        """

        path = None
        separator = None
        if dataset == 'ml-100k':
            # 共100000条数据，只有943个用户看过电影，只有1682个电影被看过。userID范围[1, 943]，movieID范围[1, 1682]。
            path = '/Users/qtt/workspace/github/SLIM-recommendation/data/ml-100k/u.data'
            separator = '\t'
        elif dataset == 'ml-1m':
            # 共1000209条数据，只有6040个用户看过电影，只有3706个电影被看过。userID范围[1, 6040]，movieID范围[1, 3952]。
            path = '/Users/qtt/workspace/github/SLIM-recommendation/data/ml-1m/ratings.dat'
            separator = '::'

        print('开始读取数据')

        # 从源文件读数据
        self.data = []
        for line in open(path, 'r'):
            data_line = line.split(separator)
            userID = int(data_line[0])
            movieID = int(data_line[1])
            # 无上下文信息的隐性反馈数据不需要评分和时间截
            #rating = int(data_line[2])
            #timestamp = int(data_line[3])
            self.data.append([userID, movieID])

        def compress(data, col):
            """
            压缩数据data第col列的数据。保证此列数字会从0开始连续出现，中间不会有一个不存在此列的数字。
            :param data: 二维列表数据
            :param col: 要压缩的列
            :return: 此列不同的数字个数（即此列最大数字加1）
            """
            e_rows = dict()  # 键是data数据第col列数据，值是一个存放键出现在的每一个行号的列表
            for i in range(len(data)):
                e = data[i][col]
                if e not in e_rows:
                    e_rows[e] = []
                e_rows[e].append(i)

            for rows, i in zip(e_rows.values(), range(len(e_rows))):
                for row in rows:
                    data[row][col] = i

            return len(e_rows)

        self.num_user = compress(self.data, 0)
        self.num_item = compress(self.data, 1)

        # 训练集和测试集
        self.train, self.test = self.__split_data()
        print('总共有{}条数据，训练集{}，测试集{}，用户{}，物品{}'.format(len(self.data), len(self.train), len(self.test), self.num_user, self.num_item))

    def __split_data(self):
        """
        将数据随机分成8份，1份作为测试集，7份作为训练集
        :return: 训练集和测试集
        """
        test = []
        train = []
        for user, item in self.data:
            if random.randint(1, 8) == 1:
                test.append([user, item])
            else:
                train.append([user, item])
        return train, test

# %%
data = Data()
# Out:
# 开始读取数据
# 总共有100000条数据，训练集87458，测试集12542，用户943，物品1682

# %%
class SLIM:
    def __init__(self, data):
        """
        稀疏线性算法。
        :param data: 无上下文信息的隐性反馈数据集，包括训练集，测试集等
        """
        self.data = data

        print('稀疏线性算法')
        self.A = self.__user_item_matrix()  # 用户-物品行为矩阵

        self.alpha = None
        self.lam_bda = None
        self.max_iter = None  # 学习最大迭代次数
        self.tol = None  # 学习阈值
        self.N = None  # 每个用户最多推荐物品数量
        self.lambda_is_ratio = None  # lambda参数是否代表比例值

        self.W = None  # 系数集合
        self.recommendation = None

    def compute_recommendation(self, alpha=0.5, lam_bda=0.02, max_iter=1000, tol=0.0001, N=10, lambda_is_ratio=True):
        """
        开始计算推荐列表
        :param alpha: lasso占比（为0只有ridge-regression，为1只有lasso）
        :param lam_bda: elastic net系数
        :param max_iter: 学习最大迭代次数
        :param tol: 学习阈值
        :param N: 每个用户最多推荐物品数量
        :param lambda_is_ratio: lambda参数是否代表比例值。若为True，则运算时每列lambda单独计算；若为False，则运算时使用单一lambda的值
        """
        self.alpha = alpha
        self.lam_bda = lam_bda
        self.max_iter = max_iter
        self.tol = tol
        self.N = N
        self.lambda_is_ratio = lambda_is_ratio

        print('开始计算W矩阵（alpha=' + str(self.alpha) + ', lambda=' + str(self.lam_bda) + ', max_iter=' + str(
            self.max_iter) + ', tol=' + str(self.tol) + '）')
        self.W = self.__aggregation_coefficients()

        print('开始计算推荐列表（N=' + str(self.N) + '）')
        self.recommendation = self.__get_recommendation()

    def __user_item_matrix(self):
        A = numpy.zeros((self.data.num_user, self.data.num_item))
        for user, item in self.data.train:
            A[user, item] = 1
        return A

    def __aggregation_coefficients(self):
        group_size = 100  # 并行计算每组计算的行/列数
        n = self.data.num_item // group_size  # 并行计算分组个数
        starts = []
        ends = []
        for i in range(n):
            start = i * group_size
            starts.append(start)
            ends.append(start + group_size)
        if self.data.num_item % group_size != 0:
            starts.append(n * group_size)
            ends.append(self.data.num_item)
            n += 1

        print('进行covariance updates的预算')
        covariance_array = None
        with ProcessPoolExecutor() as executor:
            covariance_array = numpy.vstack(executor.map(slim.compute_covariance, [self.A] * n, starts, ends))
        slim.symmetrize_covariance(covariance_array)

        print('坐标下降法学习W矩阵')
        if self.lambda_is_ratio:
            with ProcessPoolExecutor() as executor:
                return numpy.hstack(executor.map(slim.coordinate_descent_lambda_ratio, [self.alpha] * n, [self.lam_bda] * n, [self.max_iter] * n, [self.tol] * n, [self.data.num_user] * n, [self.data.num_item] * n, [covariance_array] * n, starts, ends))
        else:
            with ProcessPoolExecutor() as executor:
                return numpy.hstack(executor.map(slim.coordinate_descent, [self.alpha] * n, [self.lam_bda] * n, [self.max_iter] * n, [self.tol] * n, [self.data.num_user] * n, [self.data.num_item] * n, [covariance_array] * n, starts, ends))

    def __recommend(self, user_AW, user_item_set):
        """
        给用户user推荐最多N个物品。
        :param user_AW: AW矩阵相乘的第user行
        :param user_item_set: 训练集用户user所有有过正反馈的物品集合
        :return: 推荐给本行用户的物品列表
        """
        rank = dict()
        for i in set(range(self.data.num_item)) - user_item_set:
            rank[i] = user_AW[i]
        return [items[0] for items in sorted(rank.items(), key=operator.itemgetter(1), reverse=True)[:self.N]]

    def __get_recommendation(self):
        """
        得到所有用户的推荐物品列表。
        :return: 推荐列表，下标i对应给用户i推荐的物品列表
        """
        # 得到训练集中每个用户所有有过正反馈物品集合
        train_user_items = [set() for u in range(self.data.num_user)]
        for user, item in self.data.train:
            train_user_items[user].add(item)

        AW = self.A.dot(self.W)

        # 对每个用户推荐最多N个物品
        recommendation = []
        for user_AW, user_item_set in zip(AW, train_user_items):
            recommendation.append(self.__recommend(user_AW, user_item_set))
        return recommendation

# %%
class Evaluation:
    def __init__(self, recommend_algorithm):
        """
        对推荐算法recommend_algorithm计算各种评测指标。
        :param recommend_algorithm: 推荐算法，包括推荐结果列表，数据集等
        """
        self.rec_alg = recommend_algorithm

        self.precision = None
        self.recall = None
        self.coverage = None
        self.popularity = None

    def evaluate(self):
        """
        评测指标的计算。
        """
        # 准确率和召回率
        self.precision, self.recall = self.__precision_recall()
        print('准确率 = ' + str(self.precision * 100) + "%  召回率 = " + str(self.recall * 100) + '%')

        # 覆盖率
        self.coverage = self.__coverage()
        print('覆盖率 = ' + str(self.coverage * 100) + '%')

        # 流行度
        self.popularity = self.__popularity()
        print('流行度 = ' + str(self.popularity))

    def __precision_recall(self):
        """
        计算准确率和召回率。
        :return: 准确率和召回率
        """
        # 得到测试集用户与其所有有正反馈物品集合的映射
        test_user_items = dict()
        for user, item in self.rec_alg.data.test:
            if user not in test_user_items:
                test_user_items[user] = set()
            test_user_items[user].add(item)

        # 计算准确率和召回率
        hit = 0
        all_ru = 0
        all_tu = 0
        for user, items in test_user_items.items():
            ru = set(self.rec_alg.recommendation[user])
            tu = items

            hit += len(ru & tu)
            all_ru += len(ru)
            all_tu += len(tu)
        return hit / all_ru, hit / all_tu

    def __coverage(self):
        """
        计算覆盖率
        :return: 覆盖率
        """
        recommend_items = set()
        for user in range(self.rec_alg.data.num_user):
            for item in self.rec_alg.recommendation[user]:
                recommend_items.add(item)
        return len(recommend_items) / self.rec_alg.data.num_item

    def __popularity(self):
        """
        计算新颖度（平均流行度）
        :return: 新颖度
        """
        item_popularity = [0 for i in range(self.rec_alg.data.num_item)]
        for user, item in self.rec_alg.data.train:
            item_popularity[item] += 1

        ret = 0
        n = 0
        for user in range(self.rec_alg.data.num_user):
            for item in self.rec_alg.recommendation[user]:
                ret += math.log(1 + item_popularity[item])
                n += 1
        return ret / n

# %%
recommend = SLIM(data)
recommend.compute_recommendation()
eva = Evaluation(recommend)
eva.evaluate()
print(eva.precision)
# Out:
# 稀疏线性算法
# 开始计算W矩阵（alpha=0.5, lambda=0.02, max_iter=1000, tol=0.0001）
# 进行covariance updates的预算
# /Users/qtt/.pyenv/versions/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:69: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
# 坐标下降法学习W矩阵
# column 0 learnt 51 steps
# column 1 learnt 126 steps
# column 2 learnt 70 steps
# /Users/qtt/.pyenv/versions/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:75: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
# column 3 learnt 114 steps
# column 100 learnt 189 steps
# column 4 learnt 74 steps
# column 200 learnt 177 steps
# column 5 learnt 128 steps
# column 101 learnt 338 steps
# column 300 learnt 48 steps
# column 201 learnt 216 steps
# column 102 learnt 210 steps
# column 6 learnt 217 steps
# column 202 learnt 49 steps
# column 301 learnt 401 steps
# column 7 learnt 95 steps
# column 400 learnt 75 steps
# column 103 learnt 188 steps
# column 302 learnt 116 steps
# column 203 learnt 120 steps
# column 8 learnt 122 steps
# column 401 learnt 91 steps
# column 303 learnt 61 steps
# column 104 learnt 109 steps
# column 304 learnt 41 steps
# column 500 learnt 73 steps
# column 9 learnt 108 steps
# column 204 learnt 111 steps
# column 105 learnt 57 steps
# column 402 learnt 350 steps
# column 600 learnt 73 steps
# column 305 learnt 100 steps
# column 10 learnt 100 steps
# column 501 learnt 78 steps
# column 601 learnt 52 steps
# column 205 learnt 91 steps
# column 106 learnt 55 steps
# column 11 learnt 49 steps
# column 700 learnt 47 steps
# column 306 learnt 68 steps
# column 206 learnt 36 steps
# column 403 learnt 196 steps
# column 602 learnt 48 steps
# column 701 learnt 58 steps
# column 502 learnt 124 steps
# column 107 learnt 78 steps
# column 12 learnt 170 steps
# column 603 learnt 73 steps
# column 702 learnt 51 steps
# column 503 learnt 70 steps
# column 307 learnt 152 steps
# column 404 learnt 113 steps
# column 207 learnt 114 steps
# column 108 learnt 125 steps
# column 13 learnt 72 steps
# column 703 learnt 55 steps
# column 504 learnt 100 steps
# column 308 learnt 44 steps
# column 604 learnt 75 steps
# column 109 learnt 57 steps
# column 505 learnt 58 steps
# column 704 learnt 74 steps
# column 208 learnt 134 steps
# column 405 learnt 99 steps
# column 14 learnt 136 steps
# column 110 learnt 91 steps
# column 309 learnt 145 steps
# column 406 learnt 106 steps
# column 705 learnt 73 steps
# column 15 learnt 50 steps
# column 209 learnt 167 steps
# column 706 learnt 53 steps
# column 111 learnt 85 steps
# column 605 learnt 1000 steps
# column 407 learnt 43 steps
# column 506 learnt 163 steps
# column 310 learnt 79 steps
# column 16 learnt 75 steps
# column 210 learnt 38 steps
# column 507 learnt 37 steps
# column 606 learnt 46 steps
# column 707 learnt 79 steps
# column 508 learnt 44 steps
# column 112 learnt 220 steps
# column 607 learnt 81 steps
# column 408 learnt 221 steps
# column 311 learnt 197 steps
# column 17 learnt 121 steps
# column 312 learnt 35 steps
# column 509 learnt 61 steps
# column 211 learnt 153 steps
# column 708 learnt 187 steps
# column 18 learnt 51 steps
# column 409 learnt 69 steps
# column 19 learnt 30 steps
# column 113 learnt 140 steps
# column 313 learnt 53 steps
# column 608 learnt 90 steps
# column 212 learnt 58 steps
# column 609 learnt 34 steps
# column 213 learnt 52 steps
# column 709 learnt 66 steps
# column 510 learnt 93 steps
# column 410 learnt 369 steps
# column 314 learnt 104 steps
# column 214 learnt 39 steps
# column 20 learnt 79 steps
# column 610 learnt 58 steps
# column 511 learnt 75 steps
# column 411 learnt 40 steps
# column 710 learnt 69 steps
# column 215 learnt 63 steps
# column 114 learnt 221 steps
# column 21 learnt 69 steps
# column 611 learnt 76 steps
# column 412 learnt 65 steps
# column 512 learnt 81 steps
# column 711 learnt 50 steps
# column 612 learnt 48 steps
# column 315 learnt 131 steps
# column 712 learnt 38 steps
# column 115 learnt 77 steps
# column 216 learnt 179 steps
# column 713 learnt 34 steps
# column 513 learnt 92 steps
# column 413 learnt 80 steps
# column 116 learnt 55 steps
# column 22 learnt 194 steps
# column 714 learnt 48 steps
# column 316 learnt 75 steps
# column 613 learnt 92 steps
# column 414 learnt 49 steps
# column 514 learnt 70 steps
# column 715 learnt 38 steps
# column 515 learnt 77 steps
# column 117 learnt 113 steps
# column 614 learnt 83 steps
# column 716 learnt 37 steps
# column 415 learnt 63 steps
# column 516 learnt 54 steps
# column 317 learnt 143 steps
# column 416 learnt 55 steps
# column 23 learnt 188 steps
# column 717 learnt 73 steps
# column 217 learnt 278 steps
# column 615 learnt 78 steps
# column 517 learnt 57 steps
# column 118 learnt 178 steps
# column 318 learnt 72 steps
# column 718 learnt 62 steps
# column 616 learnt 49 steps
# column 218 learnt 85 steps
# column 119 learnt 69 steps
# column 719 learnt 79 steps
# column 319 learnt 75 steps
# column 518 learnt 83 steps
# column 617 learnt 45 steps
# column 417 learnt 121 steps
# column 24 learnt 192 steps
# column 720 learnt 47 steps
# column 519 learnt 42 steps
# column 721 learnt 22 steps
# column 120 learnt 81 steps
# column 618 learnt 90 steps
# column 25 learnt 113 steps
# column 722 learnt 40 steps
# column 520 learnt 46 steps
# column 219 learnt 136 steps
# column 418 learnt 85 steps
# column 121 learnt 86 steps
# column 619 learnt 43 steps
# column 320 learnt 207 steps
# column 419 learnt 27 steps
# column 521 learnt 47 steps
# column 723 learnt 88 steps
# column 620 learnt 40 steps
# column 122 learnt 39 steps
# column 26 learnt 159 steps
# column 420 learnt 55 steps
# column 522 learnt 44 steps
# column 220 learnt 146 steps
# column 621 learnt 64 steps
# column 421 learnt 61 steps
# column 123 learnt 64 steps
# column 523 learnt 68 steps
# column 321 learnt 217 steps
# column 27 learnt 78 steps
# column 724 learnt 346 steps
# column 322 learnt 44 steps
# column 422 learnt 135 steps
# column 124 learnt 86 steps
# column 221 learnt 145 steps
# column 524 learnt 47 steps
# column 28 learnt 66 steps
# column 622 learnt 167 steps
# column 222 learnt 37 steps
# column 125 learnt 95 steps
# column 725 learnt 128 steps
# column 525 learnt 72 steps
# column 323 learnt 88 steps
# column 126 learnt 36 steps
# column 223 learnt 48 steps
# column 29 learnt 172 steps
# column 726 learnt 49 steps
# column 127 learnt 29 steps
# column 423 learnt 148 steps
# column 526 learnt 73 steps
# column 623 learnt 107 steps
# column 324 learnt 74 steps
# column 30 learnt 52 steps
# column 624 learnt 95 steps
# column 727 learnt 57 steps
# column 128 learnt 43 steps
# column 224 learnt 243 steps
# column 625 learnt 41 steps
# column 325 learnt 89 steps
# column 728 learnt 47 steps
# column 129 learnt 59 steps
# column 527 learnt 108 steps
# column 424 learnt 96 steps
# column 729 learnt 49 steps
# column 225 learnt 87 steps
# column 130 learnt 74 steps
# column 326 learnt 80 steps
# column 425 learnt 67 steps
# column 31 learnt 264 steps
# column 131 learnt 74 steps
# column 730 learnt 104 steps
# column 327 learnt 45 steps
# column 626 learnt 1000 steps
# column 426 learnt 66 steps
# column 226 learnt 149 steps
# column 328 learnt 86 steps
# column 731 learnt 52 steps
# column 627 learnt 46 steps
# column 132 learnt 112 steps
# column 32 learnt 125 steps
# column 427 learnt 70 steps
# column 628 learnt 45 steps
# column 133 learnt 71 steps
# column 227 learnt 62 steps
# column 732 learnt 49 steps
# column 528 learnt 255 steps
# column 228 learnt 50 steps
# column 733 learnt 50 steps
# column 428 learnt 87 steps
# column 134 learnt 55 steps
# column 329 learnt 176 steps
# column 529 learnt 95 steps
# column 33 learnt 166 steps
# column 429 learnt 194 steps
# column 330 learnt 44 steps
# column 629 learnt 169 steps
# column 734 learnt 101 steps
# column 530 learnt 54 steps
# column 135 learnt 124 steps
# column 430 learnt 225 steps
# column 331 learnt 52 steps
# column 630 learnt 51 steps
# column 34 learnt 166 steps
# column 332 learnt 49 steps
# column 631 learnt 45 steps
# column 229 learnt 188 steps
# column 136 learnt 165 steps
# column 531 learnt 112 steps
# column 735 learnt 97 steps
# column 632 learnt 55 steps
# column 333 learnt 84 steps
# column 230 learnt 89 steps
# column 35 learnt 446 steps
# column 532 learnt 47 steps
# column 633 learnt 45 steps
# column 736 learnt 60 steps
# column 334 learnt 39 steps
# column 137 learnt 107 steps
# column 533 learnt 40 steps
# column 431 learnt 248 steps
# column 335 learnt 40 steps
# column 138 learnt 59 steps
# column 737 learnt 384 steps
# column 36 learnt 160 steps
# column 336 learnt 83 steps
# column 432 learnt 98 steps
# column 534 learnt 95 steps
# column 634 learnt 426 steps
# column 231 learnt 263 steps
# column 139 learnt 91 steps
# column 738 learnt 59 steps
# column 37 learnt 52 steps
# column 635 learnt 81 steps
# column 433 learnt 147 steps
# column 535 learnt 73 steps
# column 739 learnt 44 steps
# column 232 learnt 99 steps
# column 636 learnt 199 steps
# column 140 learnt 169 steps
# column 536 learnt 40 steps
# column 434 learnt 61 steps
# column 337 learnt 134 steps
# column 38 learnt 103 steps
# column 740 learnt 78 steps
# column 741 learnt 41 steps
# column 233 learnt 74 steps
# column 637 learnt 247 steps
# column 39 learnt 41 steps
# column 338 learnt 103 steps
# column 537 learnt 73 steps
# column 638 learnt 38 steps
# column 742 learnt 42 steps
# column 234 learnt 168 steps
# column 141 learnt 153 steps
# column 435 learnt 138 steps
# column 40 learnt 77 steps
# column 339 learnt 68 steps
# column 743 learnt 63 steps
# column 744 learnt 48 steps
# column 235 learnt 74 steps
# column 538 learnt 125 steps
# column 41 learnt 51 steps
# column 340 learnt 71 steps
# column 236 learnt 36 steps
# column 745 learnt 40 steps
# column 539 learnt 39 steps
# column 436 learnt 104 steps
# column 341 learnt 37 steps
# column 142 learnt 141 steps
# column 237 learnt 99 steps
# column 42 learnt 49 steps
# column 540 learnt 55 steps
# column 639 learnt 797 steps
# column 143 learnt 65 steps
# column 746 learnt 102 steps
# column 238 learnt 98 steps
# column 640 learnt 33 steps
# column 541 learnt 79 steps
# column 437 learnt 127 steps
# column 43 learnt 87 steps
# column 641 learnt 37 steps
# column 747 learnt 45 steps
# column 144 learnt 88 steps
# column 342 learnt 184 steps
# column 748 learnt 53 steps
# column 642 learnt 37 steps
# column 542 learnt 52 steps
# column 44 learnt 69 steps
# column 145 learnt 79 steps
# column 45 learnt 31 steps
# column 749 learnt 43 steps
# column 343 learnt 46 steps
# column 438 learnt 132 steps
# column 643 learnt 54 steps
# column 439 learnt 166 steps
# column 239 learnt 226 steps
# column 543 learnt 100 steps
# column 344 learnt 45 steps
# column 146 learnt 113 steps
# column 750 learnt 68 steps
# column 644 learnt 58 steps
# column 544 learnt 86 steps
# column 645 learnt 40 steps
# column 440 learnt 77 steps
# column 240 learnt 139 steps
# column 46 learnt 156 steps
# column 345 learnt 94 steps
# column 751 learnt 102 steps
# column 646 learnt 60 steps
# column 346 learnt 57 steps
# column 147 learnt 135 steps
# column 752 learnt 52 steps
# column 241 learnt 132 steps
# column 148 learnt 87 steps
# column 47 learnt 156 steps
# column 647 learnt 130 steps
# column 753 learnt 92 steps
# column 149 learnt 126 steps
# column 48 learnt 77 steps
# column 648 learnt 35 steps
# column 347 learnt 248 steps
# column 242 learnt 125 steps
# column 441 learnt 791 steps
# column 243 learnt 54 steps
# column 348 learnt 51 steps
# column 545 learnt 1000 steps
# column 150 learnt 131 steps
# column 754 learnt 141 steps
# column 442 learnt 56 steps
# column 49 learnt 155 steps
# column 649 learnt 116 steps
# column 755 learnt 34 steps
# column 349 learnt 70 steps
# column 546 learnt 97 steps
# column 350 learnt 58 steps
# column 443 learnt 80 steps
# column 50 learnt 121 steps
# column 244 learnt 180 steps
# column 151 learnt 112 steps
# column 351 learnt 91 steps
# column 444 learnt 75 steps
# column 152 learnt 65 steps
# column 245 learnt 48 steps
# column 352 learnt 46 steps
# column 650 learnt 1000 steps
# column 51 learnt 104 steps
# column 547 learnt 121 steps
# column 246 learnt 42 steps
# column 445 learnt 82 steps
# column 353 learnt 45 steps
# column 756 learnt 1000 steps
# column 153 learnt 97 steps
# column 446 learnt 39 steps
# column 52 learnt 122 steps
# column 651 learnt 60 steps
# column 548 learnt 58 steps
# column 154 learnt 87 steps
# column 652 learnt 113 steps
# column 757 learnt 69 steps
# column 447 learnt 79 steps
# column 247 learnt 222 steps
# column 354 learnt 150 steps
# column 248 learnt 53 steps
# column 53 learnt 208 steps
# column 155 learnt 72 steps
# column 549 learnt 154 steps
# column 758 learnt 163 steps
# column 355 learnt 91 steps
# column 249 learnt 96 steps
# column 54 learnt 126 steps
# column 550 learnt 107 steps
# column 156 learnt 212 steps
# column 250 learnt 77 steps
# column 551 learnt 28 steps
# column 356 learnt 137 steps
# column 759 learnt 397 steps
# column 55 learnt 72 steps
# column 760 learnt 46 steps
# column 251 learnt 68 steps
# column 357 learnt 173 steps
# column 252 learnt 55 steps
# column 157 learnt 164 steps
# column 552 learnt 136 steps
# column 653 learnt 1000 steps
# column 448 learnt 1000 steps
# column 553 learnt 46 steps
# column 358 learnt 70 steps
# column 253 learnt 134 steps
# column 56 learnt 168 steps
# column 654 learnt 72 steps
# column 554 learnt 52 steps
# column 449 learnt 79 steps
# column 158 learnt 107 steps
# column 655 learnt 58 steps
# column 450 learnt 46 steps
# column 555 learnt 66 steps
# column 761 learnt 902 steps
# column 451 learnt 32 steps
# column 359 learnt 186 steps
# column 57 learnt 246 steps
# column 656 learnt 99 steps
# column 254 learnt 224 steps
# column 762 learnt 43 steps
# column 159 learnt 131 steps
# column 255 learnt 45 steps
# column 763 learnt 54 steps
# column 360 learnt 101 steps
# column 452 learnt 111 steps
# column 556 learnt 166 steps
# column 764 learnt 48 steps
# column 58 learnt 115 steps
# column 160 learnt 90 steps
# column 657 learnt 139 steps
# column 765 learnt 43 steps
# column 453 learnt 51 steps
# column 256 learnt 214 steps
# column 59 learnt 60 steps
# column 766 learnt 118 steps
# column 361 learnt 151 steps
# column 658 learnt 289 steps
# column 257 learnt 59 steps
# column 454 learnt 87 steps
# column 557 learnt 146 steps
# column 362 learnt 59 steps
# column 767 learnt 71 steps
# column 161 learnt 209 steps
# column 659 learnt 96 steps
# column 768 learnt 44 steps
# column 258 learnt 75 steps
# column 162 learnt 48 steps
# column 455 learnt 62 steps
# column 60 learnt 152 steps
# column 259 learnt 38 steps
# column 363 learnt 149 steps
# column 769 learnt 55 steps
# column 163 learnt 54 steps
# column 660 learnt 109 steps
# column 770 learnt 44 steps
# column 558 learnt 330 steps
# column 61 learnt 108 steps
# column 164 learnt 60 steps
# column 260 learnt 119 steps
# column 559 learnt 40 steps
# column 661 learnt 46 steps
# column 364 learnt 138 steps
# column 662 learnt 30 steps
# column 261 learnt 62 steps
# column 771 learnt 61 steps
# column 456 learnt 260 steps
# column 165 learnt 70 steps
# column 560 learnt 48 steps
# column 663 learnt 51 steps
# column 365 learnt 57 steps
# column 772 learnt 38 steps
# column 62 learnt 130 steps
# column 457 learnt 47 steps
# column 561 learnt 100 steps
# column 664 learnt 42 steps
# column 262 learnt 83 steps
# column 458 learnt 71 steps
# column 773 learnt 65 steps
# column 562 learnt 56 steps
# column 665 learnt 72 steps
# column 166 learnt 195 steps
# column 63 learnt 66 steps
# column 459 learnt 46 steps
# column 774 learnt 51 steps
# column 563 learnt 35 steps
# column 167 learnt 51 steps
# column 666 learnt 46 steps
# column 775 learnt 29 steps
# column 64 learnt 54 steps
# column 564 learnt 44 steps
# column 776 learnt 37 steps
# column 168 learnt 61 steps
# column 366 learnt 191 steps
# column 263 learnt 362 steps
# column 667 learnt 53 steps
# column 460 learnt 84 steps
# column 777 learnt 61 steps
# column 169 learnt 45 steps
# column 565 learnt 60 steps
# column 668 learnt 49 steps
# column 65 learnt 134 steps
# column 566 learnt 38 steps
# column 461 learnt 135 steps
# column 264 learnt 81 steps
# column 778 learnt 88 steps
# column 170 learnt 81 steps
# column 367 learnt 193 steps
# column 171 learnt 32 steps
# column 779 learnt 51 steps
# column 567 learnt 78 steps
# column 265 learnt 48 steps
# column 368 learnt 108 steps
# column 462 learnt 92 steps
# column 266 learnt 35 steps
# column 66 learnt 148 steps
# column 780 learnt 65 steps
# column 172 learnt 109 steps
# column 369 learnt 52 steps
# column 568 learnt 66 steps
# column 669 learnt 149 steps
# column 370 learnt 37 steps
# column 569 learnt 34 steps
# column 67 learnt 63 steps
# column 173 learnt 75 steps
# column 781 learnt 73 steps
# column 267 learnt 101 steps
# column 670 learnt 64 steps
# column 570 learnt 60 steps
# column 782 learnt 76 steps
# column 671 learnt 40 steps
# column 371 learnt 94 steps
# column 68 learnt 116 steps
# column 268 learnt 68 steps
# column 463 learnt 646 steps
# column 69 learnt 37 steps
# column 672 learnt 50 steps
# column 372 learnt 80 steps
# column 783 learnt 88 steps
# column 174 learnt 192 steps
# column 269 learnt 85 steps
# column 571 learnt 153 steps
# column 70 learnt 53 steps
# column 673 learnt 64 steps
# column 270 learnt 32 steps
# column 784 learnt 45 steps
# column 464 learnt 91 steps
# column 572 learnt 35 steps
# column 71 learnt 51 steps
# column 373 learnt 104 steps
# column 175 learnt 92 steps
# column 674 learnt 37 steps
# column 271 learnt 64 steps
# column 72 learnt 72 steps
# column 176 learnt 50 steps
# column 573 learnt 111 steps
# column 675 learnt 47 steps
# column 374 learnt 93 steps
# column 272 learnt 54 steps
# column 465 learnt 150 steps
# column 574 learnt 60 steps
# column 73 learnt 85 steps
# column 177 learnt 90 steps
# column 466 learnt 47 steps
# column 676 learnt 90 steps
# column 575 learnt 77 steps
# column 74 learnt 42 steps
# column 785 learnt 533 steps
# column 178 learnt 66 steps
# column 375 learnt 112 steps
# column 467 learnt 58 steps
# column 576 learnt 63 steps
# column 786 learnt 119 steps
# column 677 learnt 79 steps
# column 376 learnt 54 steps
# column 75 learnt 83 steps
# column 577 learnt 102 steps
# column 468 learnt 91 steps
# column 273 learnt 223 steps
# column 787 learnt 90 steps
# column 179 learnt 244 steps
# column 76 learnt 147 steps
# column 578 learnt 41 steps
# column 678 learnt 66 steps
# column 377 learnt 84 steps
# column 180 learnt 39 steps
# column 274 learnt 91 steps
# column 579 learnt 32 steps
# column 378 learnt 51 steps
# column 469 learnt 82 steps
# column 580 learnt 68 steps
# column 379 learnt 36 steps
# column 275 learnt 122 steps
# column 77 learnt 184 steps
# column 181 learnt 136 steps
# column 581 learnt 59 steps
# column 380 learnt 59 steps
# column 470 learnt 72 steps
# column 679 learnt 1000 steps
# column 381 learnt 40 steps
# column 788 learnt 1000 steps
# column 582 learnt 44 steps
# column 78 learnt 121 steps
# column 276 learnt 109 steps
# column 680 learnt 49 steps
# column 182 learnt 176 steps
# column 382 learnt 75 steps
# column 789 learnt 51 steps
# column 471 learnt 188 steps
# column 583 learnt 76 steps
# column 277 learnt 77 steps
# column 790 learnt 38 steps
# column 681 learnt 55 steps
# column 183 learnt 44 steps
# column 79 learnt 108 steps
# column 383 learnt 66 steps
# column 584 learnt 43 steps
# column 791 learnt 70 steps
# column 682 learnt 62 steps
# column 184 learnt 66 steps
# column 384 learnt 59 steps
# column 472 learnt 84 steps
# column 278 learnt 123 steps
# column 585 learnt 52 steps
# column 80 learnt 64 steps
# column 792 learnt 45 steps
# column 279 learnt 49 steps
# column 683 learnt 78 steps
# column 793 learnt 76 steps
# column 385 learnt 84 steps
# column 473 learnt 80 steps
# column 586 learnt 76 steps
# column 386 learnt 48 steps
# column 684 learnt 56 steps
# column 280 learnt 101 steps
# column 81 learnt 102 steps
# column 794 learnt 76 steps
# column 185 learnt 155 steps
# column 281 learnt 43 steps
# column 474 learnt 177 steps
# column 387 learnt 73 steps
# column 587 learnt 99 steps
# column 795 learnt 59 steps
# column 685 learnt 82 steps
# column 282 learnt 73 steps
# column 588 learnt 41 steps
# column 686 learnt 37 steps
# column 388 learnt 66 steps
# column 796 learnt 65 steps
# column 82 learnt 190 steps
# column 186 learnt 120 steps
# column 475 learnt 106 steps
# column 687 learnt 73 steps
# column 589 learnt 72 steps
# column 187 learnt 45 steps
# column 283 learnt 86 steps
# column 797 learnt 64 steps
# column 476 learnt 150 steps
# column 188 learnt 61 steps
# column 798 learnt 35 steps
# column 83 learnt 169 steps
# column 590 learnt 110 steps
# column 189 learnt 88 steps
# column 799 learnt 73 steps
# column 284 learnt 111 steps
# column 477 learnt 57 steps
# column 389 learnt 195 steps
# column 190 learnt 51 steps
# column 478 learnt 118 steps
# column 84 learnt 102 steps
# column 591 learnt 94 steps
# column 285 learnt 92 steps
# column 688 learnt 1000 steps
# column 286 learnt 47 steps
# column 390 learnt 168 steps
# column 592 learnt 74 steps
# column 85 learnt 80 steps
# column 800 learnt 38 steps
# column 191 learnt 237 steps
# column 689 learnt 40 steps
# column 287 learnt 50 steps
# column 391 learnt 35 steps
# column 593 learnt 40 steps
# column 479 learnt 179 steps
# column 192 learnt 63 steps
# column 690 learnt 61 steps
# column 392 learnt 48 steps
# column 594 learnt 51 steps
# column 691 learnt 32 steps
# column 801 learnt 153 steps
# column 393 learnt 38 steps
# column 288 learnt 138 steps
# column 193 learnt 99 steps
# column 595 learnt 68 steps
# column 86 learnt 181 steps
# column 802 learnt 63 steps
# column 480 learnt 151 steps
# column 803 learnt 44 steps
# column 394 learnt 87 steps
# column 194 learnt 61 steps
# column 692 learnt 56 steps
# column 87 learnt 87 steps
# column 804 learnt 56 steps
# column 289 learnt 122 steps
# column 805 learnt 44 steps
# column 395 learnt 57 steps
# column 195 learnt 94 steps
# column 806 learnt 53 steps
# column 290 learnt 71 steps
# column 88 learnt 140 steps
# column 481 learnt 371 steps
# column 807 learnt 47 steps
# column 396 learnt 80 steps
# column 196 learnt 86 steps
# column 693 learnt 128 steps
# column 596 learnt 669 steps
# column 397 learnt 39 steps
# column 89 learnt 95 steps
# column 808 learnt 60 steps
# column 398 learnt 158 steps
# column 482 learnt 85 steps
# column 291 learnt 125 steps
# column 597 learnt 52 steps
# column 90 learnt 40 steps
# column 809 learnt 47 steps
# column 197 learnt 110 steps
# column 598 learnt 39 steps
# column 483 learnt 53 steps
# column 292 learnt 52 steps
# column 694 learnt 127 steps
# column 399 learnt 134 steps
# column 810 learnt 108 steps
# column 198 learnt 68 steps
# column 599 learnt 68 steps
# column 91 learnt 108 steps
# column 484 learnt 66 steps
# column 695 learnt 123 steps
# column 199 learnt 55 steps
# column 485 learnt 49 steps
# column 293 learnt 137 steps
# column 696 learnt 47 steps
# column 92 learnt 80 steps
# column 486 learnt 39 steps
# column 294 learnt 75 steps
# column 697 learnt 85 steps
# column 487 learnt 63 steps
# column 295 learnt 49 steps
# column 811 learnt 969 steps
# column 812 learnt 35 steps
# column 93 learnt 161 steps
# column 900 learnt 121 steps
# column 698 learnt 125 steps
# column 901 learnt 46 steps
# column 1000 learnt 99 steps
# column 813 learnt 42 steps
# column 488 learnt 102 steps
# column 1001 learnt 24 steps
# column 902 learnt 29 steps
# column 296 learnt 148 steps
# column 1002 learnt 43 steps
# column 699 learnt 50 steps
# column 814 learnt 76 steps
# column 94 learnt 138 steps
# column 1003 learnt 52 steps
# column 1100 learnt 51 steps
# column 815 learnt 35 steps
# column 903 learnt 360 steps
# column 1004 learnt 49 steps
# column 1101 learnt 53 steps
# column 816 learnt 51 steps
# column 297 learnt 178 steps
# column 904 learnt 47 steps
# column 1102 learnt 38 steps
# column 1005 learnt 81 steps
# column 817 learnt 65 steps
# column 1103 learnt 40 steps
# column 905 learnt 58 steps
# column 298 learnt 80 steps
# column 1200 learnt 182 steps
# column 95 learnt 197 steps
# column 1104 learnt 53 steps
# column 489 learnt 924 steps
# column 1006 learnt 56 steps
# column 906 learnt 62 steps
# column 1201 learnt 33 steps
# column 818 learnt 89 steps
# column 1202 learnt 92 steps
# column 1007 learnt 74 steps
# column 1105 learnt 46 steps
# column 299 learnt 99 steps
# column 490 learnt 66 steps
# column 819 learnt 66 steps
# column 907 learnt 605 steps
# column 1106 learnt 36 steps
# column 1203 learnt 110 steps
# column 1008 learnt 60 steps
# column 96 learnt 156 steps
# column 1107 learnt 45 steps
# column 491 learnt 96 steps
# column 908 learnt 66 steps
# column 1009 learnt 71 steps
# column 909 learnt 22 steps
# column 820 learnt 102 steps
# column 1108 learnt 58 steps
# column 97 learnt 92 steps
# column 821 learnt 43 steps
# column 910 learnt 46 steps
# column 1010 learnt 53 steps
# column 1301 learnt 36 steps
# column 1109 learnt 77 steps
# column 911 learnt 40 steps
# column 98 learnt 104 steps
# column 1011 learnt 44 steps
# column 1302 learnt 103 steps
# column 912 learnt 205 steps
# column 822 learnt 78 steps
# column 1110 learnt 58 steps
# column 1012 learnt 70 steps
# column 1111 learnt 24 steps
# column 1303 learnt 34 steps
# column 1304 learnt 27 steps
# column 492 learnt 177 steps
# column 823 learnt 40 steps
# column 1013 learnt 41 steps
# column 913 learnt 70 steps
# column 493 learnt 108 steps
# column 99 learnt 183 steps
# column 824 learnt 41 steps
# column 1014 learnt 45 steps
# column 1112 learnt 73 steps
# column 914 learnt 48 steps
# column 1015 learnt 36 steps
# column 494 learnt 61 steps
# column 1113 learnt 57 steps
# column 915 learnt 37 steps
# column 916 learnt 62 steps
# column 1204 learnt 1000 steps
# column 1114 learnt 58 steps
# column 495 learnt 53 steps
# column 1016 learnt 137 steps
# column 1115 learnt 51 steps
# column 825 learnt 820 steps
# column 1305 learnt 1000 steps
# column 1205 learnt 328 steps
# column 1017 learnt 36 steps
# column 826 learnt 36 steps
# column 496 learnt 127 steps
# column 1116 learnt 61 steps
# column 1206 learnt 40 steps
# column 1207 learnt 20 steps
# column 1018 learnt 64 steps
# column 497 learnt 65 steps
# column 1208 learnt 288 steps
# column 827 learnt 80 steps
# column 1117 learnt 210 steps
# column 1400 learnt 1000 steps
# column 1306 learnt 456 steps
# column 1118 learnt 43 steps
# column 1019 learnt 83 steps
# column 1401 learnt 27 steps
# column 917 learnt 1000 steps
# column 1209 learnt 352 steps
# column 1307 learnt 37 steps
# column 498 learnt 71 steps
# column 828 learnt 75 steps
# column 1210 learnt 41 steps
# column 1119 learnt 56 steps
# column 1020 learnt 66 steps
# column 918 learnt 251 steps
# column 499 learnt 63 steps
# column 1120 learnt 37 steps
# column 1021 learnt 47 steps
# column 829 learnt 64 steps
# column 1211 learnt 41 steps
# column 919 learnt 40 steps
# column 1402 learnt 394 steps
# column 1121 learnt 70 steps
# column 830 learnt 49 steps
# column 1022 learnt 47 steps
# column 920 learnt 69 steps
# column 921 learnt 42 steps
# column 831 learnt 78 steps
# column 1308 learnt 1000 steps
# column 1023 learnt 69 steps
# column 922 learnt 44 steps
# column 1122 learnt 504 steps
# column 1309 learnt 52 steps
# column 1024 learnt 43 steps
# column 832 learnt 44 steps
# column 1310 learnt 48 steps
# column 923 learnt 68 steps
# column 1123 learnt 50 steps
# column 1311 learnt 27 steps
# column 1312 learnt 13 steps
# column 1403 learnt 1000 steps
# column 1313 learnt 22 steps
# column 833 learnt 68 steps
# column 924 learnt 44 steps
# column 1212 learnt 1000 steps
# column 1314 learnt 188 steps
# column 925 learnt 41 steps
# column 834 learnt 104 steps
# column 1213 learnt 93 steps
# column 1315 learnt 96 steps
# column 926 learnt 53 steps
# column 1124 learnt 601 steps
# column 1316 learnt 69 steps
# column 1214 learnt 49 steps
# column 1500 learnt 652 steps
# column 927 learnt 53 steps
# column 835 learnt 60 steps
# column 1501 learnt 16 steps
# column 1125 learnt 226 steps
# column 1404 learnt 1000 steps
# column 836 learnt 69 steps
# column 1405 learnt 46 steps
# column 1317 learnt 135 steps
# column 928 learnt 64 steps
# column 1406 learnt 26 steps
# column 1126 learnt 45 steps
# column 837 learnt 60 steps
# column 1407 learnt 62 steps
# column 1215 learnt 477 steps
# column 1127 learnt 43 steps
# column 838 learnt 44 steps
# column 1128 learnt 38 steps
# column 839 learnt 48 steps
# column 1502 learnt 1000 steps
# column 1216 learnt 278 steps
# column 840 learnt 29 steps
# column 1318 learnt 1000 steps
# column 929 learnt 1000 steps
# column 841 learnt 44 steps
# column 1217 learnt 89 steps
# column 930 learnt 44 steps
# column 1025 learnt 1000 steps
# column 842 learnt 51 steps
# column 1408 learnt 711 steps
# column 931 learnt 67 steps
# column 1026 learnt 70 steps
# column 843 learnt 55 steps
# column 932 learnt 60 steps
# column 1027 learnt 38 steps
# column 844 learnt 51 steps
# column 933 learnt 97 steps
# column 1028 learnt 51 steps
# column 1319 learnt 922 steps
# column 1504 learnt 965 steps
# column 1218 learnt 1000 steps
# column 1029 learnt 35 steps
# column 934 learnt 41 steps
# column 1129 learnt 1000 steps
# column 1505 learnt 620 steps
# column 1219 learnt 51 steps
# column 935 learnt 43 steps
# column 1506 learnt 27 steps
# column 1220 learnt 56 steps
# column 1320 learnt 329 steps
# column 1130 learnt 618 steps
# column 845 learnt 1000 steps
# column 936 learnt 97 steps
# column 1321 learnt 222 steps
# column 1409 learnt 974 steps
# column 1410 learnt 15 steps
# column 1322 learnt 22 steps
# column 937 learnt 33 steps
# column 846 learnt 42 steps
# column 1131 learnt 459 steps
# column 1323 learnt 32 steps
# column 847 learnt 62 steps
# column 1030 learnt 1000 steps
# column 1324 learnt 118 steps
# column 938 learnt 63 steps
# column 1221 learnt 1000 steps
# column 1031 learnt 42 steps
# column 1222 learnt 35 steps
# column 1325 learnt 108 steps
# column 1032 learnt 37 steps
# column 939 learnt 50 steps
# column 1507 learnt 1000 steps
# column 940 learnt 32 steps
# column 1223 learnt 62 steps
# column 1132 learnt 395 steps
# column 1033 learnt 532 steps
# column 1327 learnt 362 steps
# column 1328 learnt 27 steps
# column 1133 learnt 178 steps
# column 1224 learnt 100 steps
# column 1508 learnt 620 steps
# column 941 learnt 615 steps
# column 1509 learnt 16 steps
# column 1034 learnt 52 steps
# column 1134 learnt 37 steps
# column 1035 learnt 44 steps
# column 1225 learnt 42 steps
# column 942 learnt 62 steps
# column 1329 learnt 616 steps
# column 1226 learnt 93 steps
# column 1135 learnt 222 steps
# column 943 learnt 137 steps
# column 1227 learnt 28 steps
# column 848 learnt 1000 steps
# column 1411 learnt 1000 steps
# column 1036 learnt 78 steps
# column 1412 learnt 16 steps
# column 1136 learnt 41 steps
# column 944 learnt 41 steps
# column 849 learnt 54 steps
# column 1228 learnt 39 steps
# column 1330 learnt 452 steps
# column 1229 learnt 32 steps
# column 1510 learnt 743 steps
# column 1037 learnt 46 steps
# column 1137 learnt 89 steps
# column 1038 learnt 24 steps
# column 945 learnt 62 steps
# column 1331 learnt 100 steps
# column 1332 learnt 10 steps
# column 1039 learnt 36 steps
# column 946 learnt 34 steps
# column 1138 learnt 53 steps
# column 1040 learnt 61 steps
# column 947 learnt 63 steps
# column 1230 learnt 624 steps
# column 850 learnt 843 steps
# column 1413 learnt 1000 steps
# column 1511 learnt 1000 steps
# column 851 learnt 40 steps
# column 1139 learnt 415 steps
# column 1512 learnt 71 steps
# column 948 learnt 54 steps
# column 1333 learnt 1000 steps
# column 949 learnt 52 steps
# column 1140 learnt 218 steps
# column 852 learnt 75 steps
# column 1041 learnt 1000 steps
# column 1334 learnt 47 steps
# column 1414 learnt 621 steps
# column 950 learnt 49 steps
# column 853 learnt 48 steps
# column 1042 learnt 34 steps
# column 951 learnt 23 steps
# column 1231 learnt 968 steps
# column 854 learnt 326 steps
# column 1043 learnt 554 steps
# column 952 learnt 230 steps
# column 1141 learnt 664 steps
# column 855 learnt 62 steps
# column 1044 learnt 48 steps
# column 1335 learnt 1000 steps
# column 953 learnt 78 steps
# column 1142 learnt 41 steps
# column 1415 learnt 1000 steps
# column 1416 learnt 46 steps
# column 954 learnt 40 steps
# column 1513 learnt 1000 steps
# column 1417 learnt 17 steps
# column 1336 learnt 126 steps
# column 1143 learnt 47 steps
# column 856 learnt 98 steps
# column 1045 learnt 357 steps
# column 857 learnt 45 steps
# column 955 learnt 50 steps
# column 1337 learnt 91 steps
# column 1046 learnt 48 steps
# column 1144 learnt 26 steps
# column 956 learnt 40 steps
# column 858 learnt 65 steps
# column 1232 learnt 1000 steps
# column 1047 learnt 48 steps
# column 957 learnt 114 steps
# column 1233 learnt 65 steps
# column 859 learnt 54 steps
# column 1145 learnt 54 steps
# column 1338 learnt 155 steps
# column 1048 learnt 63 steps
# column 1234 learnt 37 steps
# column 1514 learnt 660 steps
# column 860 learnt 83 steps
# column 1146 learnt 50 steps
# column 1418 learnt 1000 steps
# column 1339 learnt 332 steps
# column 1049 learnt 75 steps
# column 1235 learnt 111 steps
# column 1340 learnt 14 steps
# column 1419 learnt 35 steps
# column 958 learnt 535 steps
# column 1341 learnt 42 steps
# column 861 learnt 85 steps
# column 959 learnt 31 steps
# column 1050 learnt 528 steps
# column 1051 learnt 29 steps
# column 960 learnt 76 steps
# column 1515 learnt 1000 steps
# column 862 learnt 123 steps
# column 1420 learnt 1000 steps
# column 1516 learnt 25 steps
# column 961 learnt 50 steps
# column 1147 learnt 1000 steps
# column 1236 learnt 590 steps
# column 1342 learnt 1000 steps
# column 1421 learnt 105 steps
# column 1517 learnt 45 steps
# column 1148 learnt 72 steps
# column 863 learnt 48 steps
# column 1518 learnt 29 steps
# column 1343 learnt 32 steps
# column 1149 learnt 32 steps
# column 1237 learnt 82 steps
# column 1344 learnt 180 steps
# column 1150 learnt 501 steps
# column 1422 learnt 434 steps
# column 1345 learnt 168 steps
# column 864 learnt 146 steps
# column 1423 learnt 172 steps
# column 1519 learnt 547 steps
# column 865 learnt 46 steps
# column 1052 learnt 1000 steps
# column 1151 learnt 65 steps
# column 962 learnt 1000 steps
# column 1152 learnt 65 steps
# column 866 learnt 55 steps
# column 963 learnt 122 steps
# column 867 learnt 70 steps
# column 1346 learnt 583 steps
# column 1238 learnt 1000 steps
# column 1347 learnt 45 steps
# column 868 learnt 139 steps
# column 1424 learnt 1000 steps
# column 1425 learnt 19 steps
# column 964 learnt 124 steps
# column 1426 learnt 25 steps
# column 1348 learnt 61 steps
# column 869 learnt 112 steps
# column 1053 learnt 1000 steps
# column 1520 learnt 1000 steps
# column 1239 learnt 535 steps
# column 965 learnt 81 steps
# column 1349 learnt 66 steps
# column 870 learnt 51 steps
# column 1240 learnt 46 steps
# column 1350 learnt 43 steps
# column 1054 learnt 74 steps
# column 1241 learnt 39 steps
# column 1153 learnt 1000 steps
# column 1242 learnt 31 steps
# column 966 learnt 85 steps
# column 1055 learnt 42 steps
# column 1427 learnt 752 steps
# column 1351 learnt 326 steps
# column 1428 learnt 28 steps
# column 1243 learnt 48 steps
# column 1352 learnt 309 steps
# column 1056 learnt 52 steps
# column 1154 learnt 191 steps
# column 1244 learnt 44 steps
# column 1057 learnt 60 steps
# column 1521 learnt 1000 steps
# column 871 learnt 1000 steps
# column 1429 learnt 446 steps
# column 1058 learnt 38 steps
# column 1155 learnt 82 steps
# column 1245 learnt 49 steps
# column 967 learnt 548 steps
# column 1430 learnt 45 steps
# column 1156 learnt 37 steps
# column 968 learnt 42 steps
# column 1059 learnt 50 steps
# column 1157 learnt 22 steps
# column 872 learnt 60 steps
# column 1246 learnt 47 steps
# column 1158 learnt 43 steps
# column 969 learnt 41 steps
# column 1247 learnt 80 steps
# column 1522 learnt 596 steps
# column 1523 learnt 27 steps
# column 1353 learnt 707 steps
# column 1159 learnt 40 steps
# column 970 learnt 45 steps
# column 1060 learnt 152 steps
# column 873 learnt 102 steps
# column 1061 learnt 35 steps
# column 1354 learnt 38 steps
# column 1432 learnt 647 steps
# column 874 learnt 50 steps
# column 1160 learnt 306 steps
# column 1355 learnt 125 steps
# column 1062 learnt 60 steps
# column 875 learnt 50 steps
# column 1248 learnt 586 steps
# column 1433 learnt 159 steps
# column 971 learnt 110 steps
# column 1063 learnt 45 steps
# column 876 learnt 49 steps
# column 1161 learnt 258 steps
# column 1162 learnt 22 steps
# column 1524 learnt 1000 steps
# column 1249 learnt 496 steps
# column 972 learnt 56 steps
# column 1356 learnt 474 steps
# column 1434 learnt 704 steps
# column 877 learnt 75 steps
# column 1064 learnt 192 steps
# column 1250 learnt 179 steps
# column 1163 learnt 145 steps
# column 1065 learnt 40 steps
# column 878 learnt 32 steps
# column 1357 learnt 53 steps
# column 1358 learnt 16 steps
# column 1251 learnt 79 steps
# column 1359 learnt 74 steps
# column 1252 learnt 34 steps
# column 879 learnt 70 steps
# column 1164 learnt 62 steps
# column 1253 learnt 52 steps
# column 973 learnt 114 steps
# column 1360 learnt 36 steps
# column 1066 learnt 90 steps
# column 1435 learnt 413 steps
# column 974 learnt 28 steps
# column 1436 learnt 23 steps
# column 1165 learnt 120 steps
# column 880 learnt 445 steps
# column 975 learnt 46 steps
# column 1525 learnt 1000 steps
# column 1361 learnt 136 steps
# column 1067 learnt 45 steps
# column 881 learnt 56 steps
# column 1068 learnt 52 steps
# column 1254 learnt 187 steps
# column 976 learnt 96 steps
# column 1166 learnt 52 steps
# column 1069 learnt 52 steps
# column 1167 learnt 51 steps
# column 1255 learnt 149 steps
# column 882 learnt 41 steps
# column 977 learnt 49 steps
# column 1437 learnt 1000 steps
# column 883 learnt 53 steps
# column 1070 learnt 64 steps
# column 1168 learnt 46 steps
# column 1256 learnt 54 steps
# column 978 learnt 80 steps
# column 1071 learnt 46 steps
# column 1526 learnt 1000 steps
# column 1169 learnt 96 steps
# column 884 learnt 78 steps
# column 1257 learnt 49 steps
# column 1072 learnt 45 steps
# column 979 learnt 50 steps
# column 1258 learnt 36 steps
# column 885 learnt 40 steps
# column 1073 learnt 45 steps
# column 980 learnt 65 steps
# column 886 learnt 65 steps
# column 1259 learnt 56 steps
# column 1074 learnt 39 steps
# column 1170 learnt 356 steps
# column 981 learnt 49 steps
# column 1260 learnt 48 steps
# column 1438 learnt 1000 steps
# column 1171 learnt 60 steps
# column 1362 learnt 1000 steps
# column 887 learnt 61 steps
# column 1261 learnt 81 steps
# column 982 learnt 81 steps
# column 1527 learnt 1000 steps
# column 1172 learnt 41 steps
# column 1363 learnt 79 steps
# column 1262 learnt 42 steps
# column 1528 learnt 27 steps
# column 1173 learnt 184 steps
# column 1364 learnt 47 steps
# column 983 learnt 47 steps
# column 888 learnt 86 steps
# column 1075 learnt 899 steps
# column 1439 learnt 884 steps
# column 1174 learnt 78 steps
# column 1365 learnt 195 steps
# column 984 learnt 38 steps
# column 1175 learnt 42 steps
# column 889 learnt 63 steps
# column 1076 learnt 72 steps
# column 1176 learnt 32 steps
# column 985 learnt 103 steps
# column 890 learnt 51 steps
# column 1177 learnt 35 steps
# column 986 learnt 35 steps
# column 1077 learnt 46 steps
# column 1529 learnt 1000 steps
# column 987 learnt 36 steps
# column 1078 learnt 51 steps
# column 891 learnt 51 steps
# column 1530 learnt 45 steps
# column 1178 learnt 82 steps
# column 988 learnt 177 steps
# column 892 learnt 32 steps
# column 1531 learnt 31 steps
# column 1263 learnt 1000 steps
# column 1440 learnt 1000 steps
# column 1079 learnt 56 steps
# column 893 learnt 56 steps
# column 1179 learnt 61 steps
# column 989 learnt 48 steps
# column 1264 learnt 40 steps
# column 1366 learnt 1000 steps
# column 990 learnt 38 steps
# column 894 learnt 127 steps
# column 1265 learnt 40 steps
# column 1441 learnt 614 steps
# column 1180 learnt 63 steps
# column 991 learnt 44 steps
# column 1266 learnt 52 steps
# column 1367 learnt 210 steps
# column 1532 learnt 1000 steps
# column 1442 learnt 83 steps
# column 992 learnt 40 steps
# column 1181 learnt 49 steps
# column 1533 learnt 26 steps
# column 1267 learnt 51 steps
# column 895 learnt 90 steps
# column 1534 learnt 32 steps
# column 1535 learnt 16 steps
# column 1182 learnt 51 steps
# column 896 learnt 61 steps
# column 993 learnt 180 steps
# column 1183 learnt 37 steps
# column 994 learnt 44 steps
# column 897 learnt 97 steps
# column 1184 learnt 33 steps
# column 1536 learnt 146 steps
# column 898 learnt 21 steps
# column 1443 learnt 672 steps
# column 1537 learnt 23 steps
# column 1444 learnt 16 steps
# column 1268 learnt 325 steps
# column 995 learnt 38 steps
# column 1368 learnt 1000 steps
# column 899 learnt 35 steps
# column 1080 learnt 1000 steps
# column 1185 learnt 54 steps
# column 1538 learnt 225 steps
# column 1186 learnt 20 steps
# column 1369 learnt 30 steps
# column 1187 learnt 13 steps
# column 1445 learnt 281 steps
# column 1269 learnt 53 steps
# column 1081 learnt 27 steps
# column 1270 learnt 27 steps
# column 1539 learnt 17 steps
# column 996 learnt 207 steps
# column 1446 learnt 83 steps
# column 1082 learnt 32 steps
# column 1271 learnt 30 steps
# column 1540 learnt 52 steps
# column 1188 learnt 379 steps
# column 1083 learnt 52 steps
# column 1189 learnt 246 steps
# column 1084 learnt 37 steps
# column 1085 learnt 13 steps
# column 1272 learnt 523 steps
# column 1541 learnt 806 steps
# column 1190 learnt 35 steps
# column 1273 learnt 23 steps
# column 1274 learnt 16 steps
# column 1086 learnt 44 steps
# column 1191 learnt 37 steps
# column 1447 learnt 431 steps
# column 1370 learnt 1000 steps
# column 997 learnt 480 steps
# column 1542 learnt 153 steps
# column 1371 learnt 19 steps
# column 1275 learnt 241 steps
# column 1373 learnt 25 steps
# column 1087 learnt 618 steps
# column 1600 learnt 734 steps
# column 1276 learnt 102 steps
# column 998 learnt 45 steps
# column 1601 learnt 18 steps
# column 1543 learnt 159 steps
# column 1088 learnt 45 steps
# column 1192 learnt 229 steps
# column 1277 learnt 48 steps
# column 1278 learnt 29 steps
# column 1544 learnt 199 steps
# column 1089 learnt 94 steps
# column 1279 learnt 33 steps
# column 1280 learnt 26 steps
# column 1090 learnt 57 steps
# column 1281 learnt 48 steps
# column 1091 learnt 39 steps
# column 1602 learnt 1000 steps
# column 1282 learnt 25 steps
# column 999 learnt 575 steps
# column 1374 learnt 1000 steps
# column 1448 learnt 1000 steps
# column 1092 learnt 55 steps
# column 1093 learnt 33 steps
# column 1094 learnt 40 steps
# column 1375 learnt 303 steps
# column 1545 learnt 1000 steps
# column 1193 learnt 1000 steps
# column 1194 learnt 39 steps
# column 1449 learnt 433 steps
# column 1546 learnt 43 steps
# column 1547 learnt 16 steps
# column 1450 learnt 22 steps
# column 1603 learnt 1000 steps
# column 1095 learnt 51 steps
# column 1283 learnt 1000 steps
# column 1548 learnt 51 steps
# column 1195 learnt 41 steps
# column 1451 learnt 24 steps
# column 1452 learnt 84 steps
# column 1196 learnt 60 steps
# column 1453 learnt 68 steps
# column 1197 learnt 44 steps
# column 1198 learnt 25 steps
# column 1284 learnt 537 steps
# column 1604 learnt 1000 steps
# column 1605 learnt 11 steps
# column 1549 learnt 1000 steps
# column 1285 learnt 81 steps
# column 1096 learnt 1000 steps
# column 1550 learnt 32 steps
# column 1286 learnt 135 steps
# column 1097 learnt 43 steps
# column 1287 learnt 83 steps
# column 1376 learnt 1000 steps
# column 1098 learnt 40 steps
# column 1377 learnt 114 steps
# column 1606 learnt 1000 steps
# column 1288 learnt 216 steps
# column 1199 learnt 920 steps
# column 1099 learnt 55 steps
# column 1378 learnt 105 steps
# column 1454 learnt 1000 steps
# column 1551 learnt 702 steps
# column 1289 learnt 405 steps
# column 1379 learnt 80 steps
# column 1290 learnt 80 steps
# column 1291 learnt 74 steps
# column 1381 learnt 324 steps
# column 1382 learnt 20 steps
# column 1607 learnt 1000 steps
# column 1292 learnt 51 steps
# column 1455 learnt 1000 steps
# column 1383 learnt 76 steps
# column 1608 learnt 148 steps
# column 1293 learnt 138 steps
# column 1552 learnt 1000 steps
# column 1553 learnt 15 steps
# column 1384 learnt 150 steps
# column 1294 learnt 39 steps
# column 1295 learnt 48 steps
# column 1554 learnt 550 steps
# column 1609 learnt 440 steps
# column 1385 learnt 220 steps
# column 1555 learnt 31 steps
# column 1556 learnt 16 steps
# column 1456 learnt 960 steps
# column 1386 learnt 269 steps
# column 1457 learnt 127 steps
# column 1458 learnt 95 steps
# column 1296 learnt 1000 steps
# column 1459 learnt 58 steps
# column 1297 learnt 36 steps
# column 1387 learnt 148 steps
# column 1610 learnt 1000 steps
# column 1460 learnt 46 steps
# column 1557 learnt 1000 steps
# column 1558 learnt 29 steps
# column 1388 learnt 521 steps
# column 1389 learnt 61 steps
# column 1559 learnt 300 steps
# column 1613 learnt 687 steps
# column 1614 learnt 17 steps
# column 1560 learnt 74 steps
# column 1461 learnt 529 steps
# column 1561 learnt 27 steps
# column 1390 learnt 194 steps
# column 1298 learnt 1000 steps
# column 1562 learnt 20 steps
# column 1462 learnt 40 steps
# column 1463 learnt 40 steps
# column 1391 learnt 168 steps
# column 1464 learnt 541 steps
# column 1465 learnt 20 steps
# column 1299 learnt 1000 steps
# column 1615 learnt 1000 steps
# column 1563 learnt 1000 steps
# column 1616 learnt 18 steps
# column 1466 learnt 663 steps
# column 1392 learnt 771 steps
# column 1467 learnt 45 steps
# column 1617 learnt 1000 steps
# column 1618 learnt 12 steps
# column 1564 learnt 1000 steps
# column 1619 learnt 24 steps
# column 1393 learnt 1000 steps
# column 1468 learnt 1000 steps
# column 1394 learnt 30 steps
# column 1565 learnt 1000 steps
# column 1566 learnt 21 steps
# column 1620 learnt 1000 steps
# column 1469 learnt 524 steps
# column 1621 learnt 229 steps
# column 1622 learnt 20 steps
# column 1395 learnt 1000 steps
# column 1470 learnt 1000 steps
# column 1567 learnt 1000 steps
# column 1623 learnt 1000 steps
# column 1471 learnt 224 steps
# column 1624 learnt 63 steps
# column 1568 learnt 424 steps
# column 1396 learnt 1000 steps
# column 1397 learnt 49 steps
# column 1569 learnt 420 steps
# column 1570 learnt 25 steps
# column 1472 learnt 526 steps
# column 1398 learnt 68 steps
# column 1625 learnt 1000 steps
# column 1399 learnt 418 steps
# column 1626 learnt 476 steps
# column 1627 learnt 25 steps
# column 1628 learnt 17 steps
# column 1629 learnt 250 steps
# column 1571 learnt 1000 steps
# column 1473 learnt 683 steps
# column 1474 learnt 256 steps
# column 1475 learnt 27 steps
# column 1630 learnt 1000 steps
# column 1572 learnt 1000 steps
# column 1631 learnt 14 steps
# column 1632 learnt 141 steps
# column 1476 learnt 1000 steps
# column 1477 learnt 256 steps
# column 1573 learnt 1000 steps
# column 1478 learnt 237 steps
# column 1633 learnt 1000 steps
# column 1574 learnt 443 steps
# column 1479 learnt 451 steps
# column 1634 learnt 1000 steps
# column 1480 learnt 271 steps
# column 1481 learnt 41 steps
# column 1635 learnt 146 steps
# column 1482 learnt 32 steps
# column 1483 learnt 18 steps
# column 1575 learnt 1000 steps
# column 1576 learnt 69 steps
# column 1577 learnt 22 steps
# column 1636 learnt 1000 steps
# column 1637 learnt 16 steps
# column 1484 learnt 1000 steps
# column 1485 learnt 37 steps
# column 1486 learnt 154 steps
# column 1487 learnt 35 steps
# column 1578 learnt 1000 steps
# column 1579 learnt 8 steps
# column 1489 learnt 89 steps
# column 1580 learnt 620 steps
# column 1639 learnt 1000 steps
# column 1640 learnt 22 steps
# column 1641 learnt 1000 steps
# column 1490 learnt 1000 steps
# column 1642 learnt 20 steps
# column 1491 learnt 71 steps
# column 1581 learnt 1000 steps
# column 1492 learnt 230 steps
# column 1583 learnt 22 steps
# column 1585 learnt 28 steps
# column 1586 learnt 12 steps
# column 1643 learnt 1000 steps
# column 1587 learnt 425 steps
# column 1644 learnt 141 steps
# column 1588 learnt 34 steps
# column 1493 learnt 734 steps
# column 1589 learnt 22 steps
# column 1494 learnt 309 steps
# column 1645 learnt 1000 steps
# column 1495 learnt 22 steps
# column 1646 learnt 15 steps
# column 1496 learnt 26 steps
# column 1647 learnt 21 steps
# column 1590 learnt 1000 steps
# column 1497 learnt 1000 steps
# column 1648 learnt 1000 steps
# column 1649 learnt 14 steps
# column 1650 learnt 22 steps
# column 1591 learnt 1000 steps
# column 1651 learnt 141 steps
# column 1592 learnt 24 steps
# column 1593 learnt 184 steps
# column 1594 learnt 42 steps
# column 1595 learnt 371 steps
# column 1652 learnt 1000 steps
# column 1498 learnt 938 steps
# column 1499 learnt 42 steps
# column 1596 learnt 1000 steps
# column 1653 learnt 1000 steps
# column 1597 learnt 14 steps
# column 1654 learnt 1000 steps
# column 1598 learnt 1000 steps
# column 1599 learnt 20 steps
# column 1655 learnt 1000 steps
# column 1657 learnt 1000 steps
# column 1658 learnt 213 steps
# column 1660 learnt 16 steps
# column 1661 learnt 1000 steps
# column 1662 learnt 1000 steps
# column 1663 learnt 1000 steps
# column 1664 learnt 1000 steps
# column 1665 learnt 1000 steps
# column 1666 learnt 1000 steps
# column 1667 learnt 25 steps
# column 1668 learnt 1000 steps
# column 1669 learnt 1000 steps
# column 1670 learnt 22 steps
# column 1671 learnt 614 steps
# column 1672 learnt 33 steps
# column 1673 learnt 21 steps
# column 1675 learnt 156 steps
# column 1676 learnt 19 steps
# column 1677 learnt 12 steps
# column 1678 learnt 1000 steps
# column 1679 learnt 1000 steps
# column 1680 learnt 1000 steps
# column 1681 learnt 1000 steps
# 开始计算推荐列表（N=10）
# 准确率 = 27.303974221267453%  召回率 = 20.26789985648222%
# 覆盖率 = 37.03923900118906%
# 流行度 = 5.329406069284147
# 0.2730397422126745
